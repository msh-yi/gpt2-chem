# %% [markdown]
# # CHEM 584 Machine Learning Project
# ## Marcus Sak
#
# ### GPT-2 Text Generation
#
# This notebook takes in a single-column `.csv` file containing the body text of scientific articles, trains a GPT-2 model, and outputs synthetic text into a `.txt` file.

# %% [markdown]
# ### Imports
#
# We use [gpt-2-simple](https://github.com/minimaxir/gpt-2-simple), a Python wrapper for [OpenAI](https://openai.com/)'s [GPT-2 text generation model](https://cdn.openai.com/better-language-models/language_models_are_unsupervised_multitask_learners.pdf). This requires tensorflow-gpu version 1 to be installed.

# %%
import os
import requests
import tensorflow as tf  # must be tensorflow 1.x
import gpt_2_simple as gpt2
from datetime import datetime

# %% [markdown]
# Four versions of GPT-2 have been released, with 124M, 355M, 774M, and 1558M (full-sized) hyperparameters respectively. The upper limit for one commercially available GPU is the 774M model. This notebook was run on a Grace node with a single NVIDIA Tesla V100 GPU with 16GB of memory.

# %%
model_name = "774M"
if not os.path.isdir(os.path.join("models", model_name)):
    print(f"Downloading {model_name} model...")
    gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/774M/

# %% [markdown]
# ### Final data processing
#
# The final part of the data processing is handled in this notebook. In particular, we remove double quotes, empty lines, and break up the text into 1024-token chunks.

# %%
file_name = "./preproc/text_proc.csv"

# preproc leaves double quotes, remove here
if not os.path.isfile(file_name):
    print("The file does not exist")
else:
    with open(file_name, 'r') as file:
        data = file.read().replace('\"', '').replace('\n\n', '\n')

    with open(file_name, 'w') as file:
        file.write(data)

# %%
all_words = []
for line in open(file_name):
    row = line.split(' ')
    all_words += list(row)

line_breaker = 1023

# generate actual input file
gpt_input = './text_proc_2.txt'
with open(gpt_input, 'w') as file:
    for index, word in enumerate(all_words):
        if not (index % line_breaker) and index:
            # every 1023 words, make a newline
            file.write(word.strip('\n')+"\n")
        else:
            file.write(word.strip('\n')+" ")

# %% [markdown]
# ### Training GPT-2
#
# The gpt-2-simple wrapper greatly simplifies the GPT-2 interface. Training involves specifying the input file and some keyword arguments that are relatively self-explanatory. Model training was stopped at around 12000 steps after observing that the loss had plateaued and the sample output was starting to reproduce phrases in the source text.

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=gpt_input,
              model_name='774M',
              steps=20000,
              restore_from='fresh',
              run_name='run1',
              print_every=10,
              sample_every=200,
              save_every=1000
              )
# Out:
# WARNING:tensorflow:From /gpfs/loomis/project/miller/mhs65/conda_envs/gpt/lib/python3.6/site-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /gpfs/loomis/project/miller/mhs65/conda_envs/gpt/lib/python3.6/site-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/774M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/774M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:03<00:00,  3.52s/it]
# dataset has 762348 tokens
# Training...
# [10 | 24.11] loss=3.58 avg=3.58
# [20 | 34.16] loss=3.01 avg=3.29
# [30 | 44.22] loss=3.59 avg=3.39
# [40 | 54.30] loss=2.75 avg=3.23
# [50 | 64.39] loss=3.02 avg=3.19
# [60 | 74.47] loss=2.50 avg=3.07
# [70 | 84.57] loss=2.82 avg=3.03
# [80 | 94.66] loss=2.76 avg=3.00
# [90 | 104.75] loss=2.82 avg=2.98
# [100 | 114.85] loss=2.94 avg=2.97
# [110 | 124.96] loss=2.74 avg=2.95
# [120 | 135.05] loss=2.86 avg=2.94
# [130 | 145.14] loss=2.88 avg=2.94
# [140 | 155.24] loss=2.05 avg=2.87
# [150 | 165.33] loss=2.81 avg=2.87
# [160 | 175.41] loss=2.31 avg=2.83
# [170 | 185.51] loss=2.29 avg=2.79
# [180 | 195.60] loss=2.90 avg=2.80
# [190 | 205.68] loss=2.29 avg=2.77
# [200 | 215.77] loss=2.95 avg=2.78
# ======== SAMPLE 1 ========
#  stoivity, the incorporation or addition of any metal ions to the arylation products will likely result in enhanced rate and enantioselectivity. To achieve higher enantiocontrol, we explored the capacity of metal ions to influence the rates of aldination in addition to reducing the overall rate of product generation. Specifically, the addition of a metal ion to the aldehyde, as an iodine ion, or a pyrrole ion, provided reduced rates and enantiocontrol, while the corresponding iodine and pyrrole ions provided increased rates and enantioselectivity. In accord with earlier work, the rates and enantiocontrol of these coupling products are in accord with the kinetic resolution model.  We next examined the effect of various metal ions on product reactivity. A series of amines, including the a-arylation product, the d-arylation product, and the b-arylation product, led to lower rates and enantiocontrol compared to other metals ions. For example, using copper ions to enhance reactivity resulted in reduced rates of product formation, lower enantiocontrol and increased enantiocontrol. However, we were also able to achieve the highest enantiocontrol, with a k rel of 20 for both enantiomerates d-arylation products in the absence of the metal ion. In contrast, when aldehydes are exposed to the amines, they undergo accelerated reactivity that leads to decreased rates and enantiocontrol. For d-arylation products, k rel was also increased, albeit to a modest extent. For example, the amines 5 and 6 were used, the reaction rate in the presence of 5 was accelerated by 10 and 11, although still below the rate achieved in the presence of 6. Notably, the use of 6 afforded similar selectivity to the DMA-catalyst for the enantioselectivity. This is further corroborated by the lower enantiocontrol achieved. On the other hand, use of the amines 3 and 4 led to lower rate and enantiocontrol. This is the case for the amine 7, which reduces rates and enantiocontrol. Finally, the amines 3 and 4 were used as the catalyst for k rel and selectivity decreases that result from higher alkenzene substituations are observed in these compounds, which clearly indicate the importance of reducing the substituent.  We next examined the importance of controlling the substitution pattern of the carbomethyl group. In the absence of a nitrogen ion at the 3 a-position, the carbomethyl group appeared to be reduced, presumably, due to its reduced electrophility in the absence of nitrogen. Subsequent N-arylation resulted in a k rel of 11 for 6, compared to 12 obtained for 8 in an analogous system. The rate of product formation was also significantly lower in comparison to the dMA-catalyst. As predicted from the kinetic resolution model, a series of N-ortho substitutions at the 5 a position led to faster rate and enantioselectivity in comparison to the other substitutions for the 6 a-position. Moreover, substituting the carbomethyl group of DMA-catalyst 7 for the carbon carbon group in DMA-catalyst 3 was more deleterious to product induction without loss in enantioselectivity. In fact, we were able to obtain a k rel for 8 that is similar to the rates achieved in the analogous system in the presence of DMA-catalyst 3. It is important to note that the carbomethyl substitations were not accompanied by substantial alterations in enantiocontrol, which is consistent with the mechanistic hypothesis outlined in Scheme 1.  Our studies have highlighted the significance of using iodines as an enantioselective aldination tool to enhance eCdS reactivity in a general sense. While iodine-based catalysts were proposed to be superior in various contexts, we have also found that iodine catalysis has significant limitations with respect to the arylation product formation. It must be stressed that iodine and iodine-based catalysts are not superior substrate delivery mechanisms. For example, we have also found that iodines alone are inadequate catalysts for generating a range of arylated alcohol mol ...
#
# [210 | 250.30] loss=1.51 avg=2.71
# [220 | 260.37] loss=3.32 avg=2.74
# [230 | 270.45] loss=1.90 avg=2.70
# [240 | 280.54] loss=2.94 avg=2.71
# [250 | 290.62] loss=2.54 avg=2.71
# [260 | 300.71] loss=3.56 avg=2.74
# [270 | 310.79] loss=2.86 avg=2.75
# [280 | 320.88] loss=2.33 avg=2.73
# [290 | 330.96] loss=3.61 avg=2.77
# [300 | 341.05] loss=2.08 avg=2.74
# [310 | 351.14] loss=2.66 avg=2.74
# [320 | 361.22] loss=3.11 avg=2.75
# [330 | 371.31] loss=2.04 avg=2.73
# [340 | 381.40] loss=3.52 avg=2.75
# [350 | 391.48] loss=2.20 avg=2.73
# [360 | 401.57] loss=2.41 avg=2.72
# [370 | 411.66] loss=3.16 avg=2.74
# [380 | 421.74] loss=1.51 avg=2.70
# [390 | 431.82] loss=3.07 avg=2.71
# [400 | 441.90] loss=2.27 avg=2.70
# ======== SAMPLE 1 ========
#  113 in the 3p oxidation state of the Ni species and thus higher reactivity, suggesting stronger cation interactions between the metal and carbon atoms of the Ni species. At the same time, we have been curious about the extent to which the Cs ions have interacted with the amine nucleoide -3. Since we have found a very high amount of NH oxidation of Ni in our experiment, we presume that the Cs ions are forming a highly oxidizing species. On the other hand, we have seen a very low amount of Cs ion deprotonation, at least according to the EC 3 experiment, which seems inconsistent with strong cation interactions between the Ni iodide and amine nucleiide.  Last, we reasoned that, under the same mechanism, a higher energy or lower energy amine species might be formed. This would explain why the Cs ions are not observed in these higher energy systems in the 3-p oxidation state.  It has been established that aqueous solvents and high temperatures lead to enhanced cation interaction between the metal and the oxygen atom of the amine nucleoide. This interaction can be inhibited, however, by low temperatures of solubility. Thus, even within the best solvent conditions, aqueous-solvents are not effective in dissociating cationic aluminum atoms from the amine nucleiide at low temperatures or at low solubility.  In terms of solubility of the Cs ions, a significant amount is produced when solubility is decreased, which indicates that low temperatures are not competitive with the Ni ions for the formation of the Cs ion. The opposite is true at low temperatures, when low solubility appears to inhibit thermal dissociation.  The high selectivity of the EC 3 experiment with anodized Ni is also intriguing. It is notable that anodized Ni is the most soluble electrophilic of all of the common electrophiles. This is consistent with prior evidence for the formation of many heteroatom Cs cation combinations, leading to low solubility. The fact that Cs cannot escape the pivalamide species, which possess the strongest Cs ion binding attachment, suggests that high levels of metalicity are needed to achieve high selectivity in this reaction.  As revealed in, these Ni nucleophiles do not degrade in solubility. When solubility is lowered to 1 M in toluene with 20 C, the Cs ions retain their value as an electrophile that can dissociate a significant amount in toluene. In the case of aqueous solvents, a slight decrease in solubility may be detected, such as a decrease in yield, but when exposed to cold toluanes, a significant loss in solubility is completely undetectable. As revealed in, Ni does not lose any selectivity in the reaction. Thus, the low solubility of Ni is not a serious source of the observed low selectivity.  Given the very high selectivity exhibited by aqueous solvents and that of cold toluene, anodized Ni should be the most electrophilic electrophilic of the electrophiles studied herein.  It should be noted that, in general, higher temperatures lead to diminished solubility. For example, a lower temperature is required to reach a similar selectivity in the case of chloroform, dioxane, nitroform, p-nitroform, chloroform. Toluene was the optimal temperature tested, with a temperature range ranging from 20 C to 40 C. It should be noted that a lower temperature was also tested for this reaction, and the EC 3 experiment is somewhat less selective. Based on the higher selectivity and the fact that aqueous solvents are poor solubility systems in this reaction, we suggest that high temperatures are not generally a competitive source of the cation ion separation. The fact that the low selectivity observed by cold toluene was not observed in chloroform, dioxane, nitroform, nitroform, p-nitroform, chloroformat, dioxane, nitroform, p-nitroform, chloroform is consistent with the fact that the cation is not formed when cold toluene is used as solvent. This finding is a significant consequence of the higher temperature environment in the reaction reaction.   ...
# [410 | 471.76] loss=3.08 avg=2.71
# [420 | 481.83] loss=2.69 avg=2.71
# [430 | 491.91] loss=2.24 avg=2.69
# [440 | 501.99] loss=2.26 avg=2.68
# [450 | 512.08] loss=1.30 avg=2.64
# [460 | 522.16] loss=2.35 avg=2.64
# [470 | 532.24] loss=2.76 avg=2.64
# [480 | 542.33] loss=3.60 avg=2.66
# [490 | 552.42] loss=2.71 avg=2.67
# [500 | 562.51] loss=1.39 avg=2.63
# [510 | 572.60] loss=3.19 avg=2.65
# [520 | 582.69] loss=2.39 avg=2.64
# [530 | 592.78] loss=2.72 avg=2.64
# [540 | 602.86] loss=3.01 avg=2.65
# [550 | 612.94] loss=2.14 avg=2.64
# [560 | 623.02] loss=2.51 avg=2.64
# [570 | 633.11] loss=1.98 avg=2.62
# [580 | 643.19] loss=2.17 avg=2.61
# [590 | 653.27] loss=2.73 avg=2.61
# [600 | 663.36] loss=2.86 avg=2.62
# ======== SAMPLE 1 ========
#  as i, j, k clusters or as a single point. Thus, we chose not to make use the simple i, z-imaging techniques discussed previously for the Hs-HPLC.  As noted previously, we employed the 3. 0-BINOL-HCl catalyst 3-nitrobenzoic acid as a catalyst for the asymmetric BINOL-BINOL linkage reaction. This catalystsubstrate interaction mechanism was first demonstrated in the context of cyclohexanol and chlorohexose and has been extended and elaborated to include a wide range of chemical systems. Recent work on the acylation of aldehydes through benzyloxyproline catalyzed nitroglone imine formation has shown that peptide-based catalysts can catalyze the asymmetric nitrochiral nitro-pyridine nitro-pyridine nitro-Ns-Bn-Phe-OMe-BNp-Phe-POxy. In light of studies on nitro-chiral nitro-A -nitrobenzyl -nitrobenzoic acid-Ns -n-imines, we anticipated that this catalyst will be more readily employed for nitro-chiral nitro-nitro reactions. Thus, we evaluated several catalystsets of nitro-nitro reactions based on enantioselectivityand catalyst-substrate interactions, and found a catalyst that provides high enantioselectivity. We attribute this catalyst-substrate interaction-imine coupling mechanism to the selectivity afforded by the urea aspartic acid catalysts, with the enantioselectivity provided by the peptide 2, 3-dinitryldoic acid derivative 2.  Enantioselective nitro-nitro reactions of cyclohexythyl p-butylidene acetals proceed via catalyzed anilines: catalyzed BINOL-PYRNA-P-Phe-PNP sequence extension is the site of stereocontrol. By a structural comparison of catalyst 2. 1 -2. 3, we identified catalysts with different enantiomeric ratios that favor the desired nitro-nitro aromatic cyclizations in excellent yield. With enantiomer selectivity, the catalyst provides high levels of enantioselectivity. An excellent example of a peptide catalyst that provides high enantiomeric ratios in the nitro-nitro cyclizations is catalyst 2. 5 -2. 5, which provides the optimal enantiomeric ratio in the nitro-nitro cyclizations. Furthermore, the addition of a 3:1 ratio in the nitro-nitro cyclization further improves the enantiomeric ratio to 20:1.  The catalyst 2. 7 is slightly lower favoring the nitrocyclization reactions using its catalytic P-hydroxysulfonyl-P-D-PNP motif. In each case, enantiomeric ratios were slightly lower. These catalysts provide modest yields of cycloheptyl nitro reactions using this structure. However, the nitrocyclization reactions have been extensively studied, and these catalysts are effective for many cyclizations.  We recently asked whether or not catalysts based on 2, 3-dinitryldoic acid derivatives might function as a nitro-nucleophile catalyst in the nitro-nitro cycle. To the extent that nitro-nitro reactions from aldehydes based on catalysts, catalysts, or inhibitors might function for nucleophile activation and nitro-nitro cyclization. We have already identified peptide-based catalyzes that exhibit excellent levels of enantiomeric ratios for nitrocyclization reactions. These catalysts employ the simple 2, 5dinitryldoic acid. We further evaluated catalysts that provided high enantioselectivities in an enantiomeric ratio of 4, 5-dinitrophenol, 1. 5-dioxynhydroxylamine, and in nitrocyclization reactions. Peptide 2. 4, which is characterized by a D-Pro-Aib -D-Aib -D-Pro sequence extension, provided very high enantiomer ratios in the nitrocyclization reactions with a moderate 2. 4 enantiomer ratio of 2. 3, and was observed with substantial substrate substrate reactivity and er for the nitrocyclization reactions. In addition, the addition of catalysts containing 2, 3-dione as a N-terminal N, N-dimethylacetamidite and as a BINOL-PYRNA-P-Phe-PNP sequence extension provided nitrocyclization reactions with excellent enantiomeric ratios. For the nitrocyclizations, a reasonable catalyst-substrate interaction mechanism was observed. The reaction with 2. 5 -nitrobenzaldehyde proceeded with high catalyst loadings and substrate reactivities.
#
# [610 | 693.20] loss=2.84 avg=2.62
# [620 | 703.27] loss=2.90 avg=2.63
# [630 | 713.34] loss=1.79 avg=2.61
# [640 | 723.42] loss=2.83 avg=2.62
# [650 | 733.50] loss=2.45 avg=2.61
# [660 | 743.59] loss=2.30 avg=2.61
# [670 | 753.67] loss=1.83 avg=2.59
# [680 | 763.74] loss=2.84 avg=2.60
# [690 | 773.83] loss=1.96 avg=2.58
# [700 | 783.91] loss=1.41 avg=2.56
# [710 | 794.00] loss=2.99 avg=2.57
# [720 | 804.08] loss=2.74 avg=2.57
# [730 | 814.17] loss=3.15 avg=2.58
# [740 | 824.25] loss=2.93 avg=2.59
# [750 | 834.33] loss=1.69 avg=2.57
# [760 | 844.41] loss=1.01 avg=2.54
# [770 | 854.50] loss=2.16 avg=2.54
# [780 | 864.57] loss=3.35 avg=2.55
# [790 | 874.66] loss=1.81 avg=2.54
# [800 | 884.73] loss=2.57 avg=2.54
# ======== SAMPLE 1 ========
#  First the reaction was heated to 80C in C18 cells overnight. In the morning, the cells were lysin-fixed with diethyl ether. The cells were resynthesized in diethyl ether overnight. The cells were centrifuged in diethyl ether at 80 8C for 2 h and then washed with diethyl ether and brine. The cells were collected and placed in fresh diethyl ether overnight. After the cells were lysin-fixed, the cells were plated in a 96well plate with diethyl ether. The cell pellet was placed in a separate vessel. After the cells were plated in a 96well plate, the cells were incubated with diethyl ether for 24 h. Each time the cells were incubated without diethyl ether for 1 h, the cells were treated with diethyl ether and then rinsed with water and brine. When a reaction was carried out in the presence of diethyl ether, the diethyl ether was removed and the reaction was stored in its own well of a solution. In a separate medium, diethyl ether was heated at 80C in a solution containing diethyl ether and diethyl ether. The mixture was then filtered to reduce the diethyl ether to diethyl ether. After the diethyl ether was purified in HPLC, the reaction was filtered through Celite. The resulting brownish colour was taken at pH 9C, filtered through Celite and finally concentrated in diethyl ether. The crude product was then allowed to cool to 0C and then to the concentration station without further purification.   This simple and highly functionalized reaction, which was demonstrated to allow the construction of complex and biologically active compounds in an environmentally benign manner, was first reported by Gellman and co-workers. A number of subsequent contributions from this group have been reported. One aspect that attracted the interest of the researchers over the initial report was the development of cross diastereoselective polyol reactions. For example, cross-polar cross-couplings with aldehydes.  A second aspect that attracted the interest of this report was the use of amino acids and peptides for reactivity. A small library of peptide-based catalysts were explored. Most of the peptides in the library contain the BOC-Ala sequence and a single amino acid side chain. The most notable result with respect to the use of amino acids for cross-coupling is that approximately 70 of the peptides were found to be effective, albeit with a moderate number of poorly performing peptides. When the reaction is performed with a peptide containing the Boc sequence only, the reaction was found that a number of the amino acids selected for reactions under the conditions discussed in Scheme 2, and the reaction yield, if any, was notably high.  To evaluate the efficacy of peptides 4 and 16. The efficacy of peptide 4 was investigated. The reaction of aldehydes with acetonitrile is well-known and has been known to yield high yields for years. One problem, however, is the large size of the aldehyde and the small number of amino acids that can be catalytically incorporated into large molecules. In these cases, catalyst design has provided opportunities for flexibility, especially with respect to the presence of non-natural, unnatural, or partially substituted amino acids. That is, to create synthetically useful polyol motifs for use in large and diverse structures, and in conjunction with other novel and known methods for asymmetric reactions. We felt that we had high potential to apply this synthetic technology in this context, especially with respect to the possibility of using an amino as a starting place for further catalyst development. A few examples of peptide-based cross-coupling reactions that have been achieved are presented below.  In these cases, we have described highly diastereoselective reactions that have been executed enantioselectively. In this paper, we report peptide-based solutions to this challenge. In the context of the present reaction, we have developed a peptide-based approach to the enantioselective synthesis of natural products. The me ...
# [810 | 914.60] loss=2.82 avg=2.54
# [820 | 924.67] loss=2.22 avg=2.54
# [830 | 934.74] loss=2.19 avg=2.53
# [840 | 944.82] loss=1.85 avg=2.52
# [850 | 954.90] loss=1.71 avg=2.51
# [860 | 964.98] loss=1.31 avg=2.48
# [870 | 975.05] loss=1.86 avg=2.47
# [880 | 985.12] loss=1.69 avg=2.46
# [890 | 995.19] loss=2.42 avg=2.46
# [900 | 1005.26] loss=1.55 avg=2.45
# [910 | 1015.33] loss=1.73 avg=2.43
# [920 | 1025.39] loss=1.69 avg=2.42
# [930 | 1035.46] loss=2.33 avg=2.42
# [940 | 1045.54] loss=2.97 avg=2.43
# [950 | 1055.60] loss=1.33 avg=2.41
# [960 | 1065.67] loss=2.16 avg=2.41
# [970 | 1075.74] loss=1.50 avg=2.39
# [980 | 1085.81] loss=2.27 avg=2.39
# [990 | 1095.87] loss=0.50 avg=2.36
# [1000 | 1105.95] loss=0.97 avg=2.34
# Saving checkpoint/run1/model-1000
# ======== SAMPLE 1 ========
#  giving. However, in the two prior examples of this reaction, the catalyst 1 that was most active was identified. In each of the prior studies, catalyst 1 was found to be monocatalyzed. In the present study, the catalyst that is most active is
# called 5. The catalyst for the reaction is called 2. These results demonstrate that catalyst 2 is the most active catalyst for this reaction, which further indicates that the catalyst-controlled stereodifferentiation of ketones is the fundamental reaction that is responsible for catalysis of the reaction. These results further highlight the role that achiral catalyst-controlled stereodifferentiation can have on catalyst performance in complex settings. In this particular case, achiral catalyst 2 provides the catalyst for a highly stereoselective reaction that can be carried out by differentially substituted ketones. While catalysts that deliver different stereoisomers of ketones each reactivity is matched with a different enantiomer of ketone, each enantiomer is found to react more selectively than the other enantiomers. This result might provide a mechanistic insight into the enantiodivergent functional group selectivity that catalysts are able to achieve in environments with limited chiral support. Another way the present study might work is by monitoring the rate of reaction of different enantiomers of ketones. In a separate study, chiral catalyst 2 was found to be able to catalyze the reaction of racemic 2-phenyldimethylpiperidine and cyclohexanone 10 a ketone is the first amino acid to form a peptide. Therefore, catalysts are able to choose a position on a peptide, called a chirality, that will provide the catalytically active phenyl ester or amine. This allows catalyst 2 to match enantioenriched ketones of different enantiomers with different enantiomerically enriched, chiral amino acids. These processes are complex and have been accomplished many times. For example, one enantiomer of 4-methylphenyldimethylpiperidine undergoes catalyst-controlled, stereoselective oxidation of cycloheptanone to its corresponding cyclohexanone. A second enantiomer of the same catalyst is found in the reaction of cycloheptanone 13 to give cyclohexanone 14. This enantiomeric selectivity is thought to be a consequence of the chirality of the catalyst. However, the two enantiomers are observed as different enantiomers of the cycloheptanone, a phenomenon that is consistent with enantioenriched ketones reacting selectively to yield the desired cyclobutane derivatives.  This enantioselective catalyst-controlled enantioselective ketone oxidation provides a striking example of a reaction where catalyst controls both enantiomeric catalysis of the desired reaction product, and enantiomeric catalysis of the product. This is particularly true in light of the fact that ketones can be prepared from achiral precursors and used to selectively prepare the corresponding cyclic ketones, which appear enantiomeric at reaction temperatures. For example, enantiomeric catalysts that lead to cycloheptanones with low k 2 ar. ketones, such as catalysts that give higher k 2 enantiomeric selectivity for alkyl-substituted aldehydes, could present a challenging set of reactivities for catalyst 2 to control. As a followup study, this approach was applied to aldehydes that are enantiopure, an option that is increasingly common for the synthesis of enantiomers. When the catalyst and substrate are employed together, catalyst 2 presents a formidable challenge for substrate control. Thus, enantiomerically enriched, cyclohexenone-containing compounds present in the reaction conditions, may appear in the same reaction medium as catalyst 2. Under these conditions, substrate inhibition and regioselectivity are present, leading to substrates that are monophosphorylated or nearly so. These results represent a challenging case for catalyst 2 because it presents substrates that are potentially monophosphorylated and enantiopure, and its is thus presented as a second enzyme. This is clearly a scenario in which substrate and catalyst are matched appropriately.  In 1997, Ting and co-workers reported a series of enzymatic catalysis reactions that utilized the enzyme linolenovoic acid to c ...
#
# [1010 | 1141.14] loss=1.67 avg=2.33
# [1020 | 1151.19] loss=1.29 avg=2.31
# [1030 | 1161.25] loss=1.27 avg=2.30
# [1040 | 1171.33] loss=0.95 avg=2.27
# [1050 | 1181.41] loss=1.78 avg=2.27
# [1060 | 1191.49] loss=1.93 avg=2.26
# [1070 | 1201.58] loss=2.01 avg=2.26
# [1080 | 1211.66] loss=2.34 avg=2.26
# [1090 | 1221.74] loss=1.67 avg=2.25
# [1100 | 1231.83] loss=1.83 avg=2.24
# [1110 | 1241.91] loss=2.07 avg=2.24
# [1120 | 1251.99] loss=0.85 avg=2.22
# [1130 | 1262.07] loss=2.22 avg=2.22
# [1140 | 1272.15] loss=1.41 avg=2.21
# [1150 | 1282.24] loss=2.96 avg=2.22
# [1160 | 1292.32] loss=1.96 avg=2.22
# [1170 | 1302.41] loss=2.44 avg=2.22
# [1180 | 1312.48] loss=1.27 avg=2.21
# [1190 | 1322.56] loss=2.27 avg=2.21
# [1200 | 1332.65] loss=3.04 avg=2.22
# ======== SAMPLE 1 ========
# yl. This effect is believed to be closely related to the observed decrease in the catalytic efficiency when using L-3-butane over a previously studied Csp 2 O 2 -O cation. The decreased reactivity seems to be closely related to the reduced mole fraction of the product relative to reactions using O-acyl and O-acryl as the respective replacement for L- 3-butane.   The observed decrease in yield when using acrylate-containing peptides has also been questioned. We were unable to obtain a single yield at temperatures greater than 0C for these reactions. We postulate that, due to the unfavorable HOMO charge transfer from the solvent maturation pocket via the primary amine, the reaction can't proceed at room temperature, which further limits the range of product that may be obtained. Furthermore, at greater concentrations, the formation of acrylate is likely to become more complicated.  The relative reactivity of Ac, Et and Au as a function of acrylate solvent maturation has been questioned. We present the results for Ac, Et and Au.  the data are available in supplementary information, supporting the conclusion that only the lowest-energy Au is engaged in a competitive association with the Ni catalyst. Additionally, the reactivity data for the Ac, Et and Au systems versus their Au counterparts are shown in.  The greater selectivity for Ac, Et and Au as a function of solvent maturation is most likely due to the higher HOMO energy of Au relative to the other two systems as their greater solvent accessibility will allow greater protonation of Au the higher intrinsic rate of Au will further increase the increase in the rate of the protonation, leading to increased overall rate, thus leading to greater selectivity for the overall process.
# The data also support the hypothesis that these higher selectivity levels are maintained through interactions between the tertiary amine and O-acyl, presumably to facilitate the reduction of Au.  An examination of the peptide sequence reveals that is not only compatible with the results of the original experiment, but likely the highest levels of selectivity for the first-order homologous series. While the lowest-energy Au, Ac and Au schemes did not outperform the higher-energy Ac, Et and Au schemes, the lowest-energy Ac, Et and Au schemes were significantly less selective, and even the most selective for the 1storder homologous series. Despite this, the Au scheme is likely the most selective for the series, because of the limited number of stereocenters on the single-turn system and the higher number of conformational states available to the 2, 7-trifluoromethylated amine compared to the 2, 4-trifluoromethylated amine, which is the most selective in the series.  The data support our proposed mechanism for the selectivity achieved with the optimized sequence. While no one scheme can ever be completely optimized due to the number of different bicyclic structures that may populate the same set of structural spaces, we do believe the optimized solution to the acrylate reduction is consistent with the high level of stereoselectivity achieved in this case. However, this does not change the fact that the number of acrylates that may be generated by reduction of a complex precursor, including bicyclic -amino acids, is considerably greater than the number of aryl rings, which contain similar structural elements. Thus, it is likely that the rate of the overall reaction, in terms of product isolation, diminishes as compared to the analogous reaction containing only a single unit.  The fact that the 3, 3-aarylation is likely to be slower than that of the 1, 1-arylation points to the need to achieve substantial substrate control over the reduction of 1 to afford a stable, robust -alkyl carbon, which is difficult to achieve via catalysis. For example, in the 3, 3-borylation, it is likely that the control of the -alkylation of 1 will be exerted in this case due to the inherent low -stereocontrol. A more intricate control over the reduction is due to the presence of the 3, 3-aryl group, which can be placed on the anilinic nitrogen of the amine in order to effectively shield the re-face of the amide, resulting in the reduction of 1 to an unselective -alkyl. The loss of 4 will reduce the rate of the -aryl reduction, in comparison to the other schemes. However, this effect reverses when the nitrogen of the amine is converted to amine -aldehyde, thus increasing the rate of the reaction.  The selectivity of the 3, 3-aryl reduction is thus affected by the steric demands of the amine unit. However, it is interesting that the rate of the reaction is decreased when the amine is replaced with the amine -aldehyde. If sterically demanding amines are substituted on the amine, then
# [1210 | 1362.61] loss=2.41 avg=2.22
# [1220 | 1372.68] loss=1.52 avg=2.21
# [1230 | 1382.76] loss=2.03 avg=2.21
# [1240 | 1392.84] loss=1.70 avg=2.20
# [1250 | 1402.93] loss=3.16 avg=2.22
# [1260 | 1413.01] loss=2.26 avg=2.22
# [1270 | 1423.09] loss=2.60 avg=2.22
# [1280 | 1433.18] loss=2.80 avg=2.23
# [1290 | 1443.27] loss=1.55 avg=2.22
# [1300 | 1453.35] loss=1.40 avg=2.21
# [1310 | 1463.44] loss=2.28 avg=2.21
# [1320 | 1473.52] loss=1.57 avg=2.20
# [1330 | 1483.60] loss=1.03 avg=2.18
# [1340 | 1493.68] loss=1.30 avg=2.17
# [1350 | 1503.77] loss=1.49 avg=2.16
# [1360 | 1513.85] loss=1.49 avg=2.15
# [1370 | 1523.93] loss=1.18 avg=2.14
# [1380 | 1534.01] loss=0.77 avg=2.12
# [1390 | 1544.10] loss=2.10 avg=2.12
# [1400 | 1554.18] loss=1.23 avg=2.11
# ======== SAMPLE 1 ========
#  In NMR Spectra, Hnigs base is a very minor player in the picture, with only 2 ppm of Hnigs base. But on a larger scale, these compounds exhibit very different NMR spectra. Whereas the CD, IR, and Hnigs bases are all labeled to some extent in the literature, the PPh 3-labeled variety is often completely non-labeled. Moreover, unlike the CD, IR, and PPh 3 labels, the CX, CZ, and CY derived from the C8-CZ bond are missing a PH 3 group. These two sets of catalysts exhibit very different, non-identifying, or enhanced, IR resonances than the others. However, the degree to which the stereochemistry in these acylated peptides has varied across the catalyst series is also unknown. The structural features that confer functionality to the catalysts in each series are also different. This creates a curious discrepancy between the states that Hamilton and Weix have depicted in their work. Whereas Hamilton has presented structural attributes relevant to the uniformity of functionalization throughout the peptide-catalyzed acylation of cis-hexans, Weix has focused on the more dynamic and phenol substructures. In particular, C-terminal allylsilanes and isochrones have been the subject of extensive studies. The basis of the divergent behavior of the two enantiomers of catalyst 9 is also uncertain, although recent work suggests that similar transition states lead to equivalent structures in the bis-catalyzed BVO as they both follow the same general trend of b-turn secondary structure. Whereas all three catalysts follow the same general turn motif, Boc Pmh is conformationally different. Whereas the C-terminal residue of 9 is oriented such that it leads to two ortho-ortho interconverting states, the C-terminal edge of Pmh leads to a different, noncombining mode. For this reason, the two enantiomers of 9 differ in both secondary structures. Additionally, the two modes of hydrogen bonding between the tertiary amine NH and O are different. Whereas the Cxis is strong, the Cye is stronger, leading to two mixed modes. Lastly, the two modes of HS-Boc Pmh are different as well. Whereas the Cxis leads to mixed modes, the Cye leads to a single, undifferentiating mode.  In discussing each catalytically active conformer under the umbrella of type I and II conformers, we first discussed the advantages of the former conformer in terms of the catalysts ability to be used as a source of functional groups and the advantages of utilizing a chiral environment such as a peptide. We then discussed the disadvantages and advantages of the latter conformer, as these aspects were found to influence the activities and selectivity of the catalyst tests. While the former conformer is indeed quite LOU sensitive, the large standard deviation of the data set means that there are likely thousands of other structures that could be generated in the presence of simple peptide catalysts. Thus, the question remains as to whether a single, universal catalyst could produce sufficient enantioselectivities to be used for all cases. We currently conclude that, under the appropriate conditions, a single catalytic peptide could provide a reasonable approximation of sufficient enantioselectivities in the presence of relevant substrates.  With the development of a universal catalyst for the treatment of a given scaffold in hand, the next question is what substrate types would be compatible with the new catalysts, given the substantially different substrate microenvironment. The answer to this question appears to be: any substrate that contains a large number of similar functional-groups-indeed, any structure that contains a small number of conserved functional-groups-is likely to be amenable to catalyst interaction. As a result, there will likely be specific interactions exhibited by the catalyst that are specific to each structure. This is why the specific interactions below have been important. As a next step, we determined that it would be useful to identify a methodology for the rapid ca ...
#
# [1410 | 1584.07] loss=1.85 avg=2.11
# [1420 | 1594.14] loss=1.81 avg=2.10
# [1430 | 1604.21] loss=2.43 avg=2.11
# [1440 | 1614.29] loss=0.98 avg=2.09
# [1450 | 1624.38] loss=1.00 avg=2.08
# [1460 | 1634.48] loss=0.64 avg=2.06
# [1470 | 1644.56] loss=1.08 avg=2.05
# [1480 | 1654.65] loss=3.02 avg=2.06
# [1490 | 1664.73] loss=2.02 avg=2.06
# [1500 | 1674.82] loss=0.74 avg=2.04
# [1510 | 1684.91] loss=1.99 avg=2.04
# [1520 | 1695.00] loss=0.68 avg=2.02
# [1530 | 1705.09] loss=2.33 avg=2.03
# [1540 | 1715.17] loss=0.36 avg=2.01
# [1550 | 1725.26] loss=1.45 avg=2.00
# [1560 | 1735.34] loss=2.06 avg=2.00
# [1570 | 1745.43] loss=1.12 avg=1.99
# [1580 | 1755.51] loss=2.19 avg=1.99
# [1590 | 1765.59] loss=1.49 avg=1.99
# [1600 | 1775.68] loss=0.76 avg=1.97
# ======== SAMPLE 1 ========
#  palette of C5 with C18 in CH 2 Cl 2 and buffered 1. 15 at 4C.  The scope of these reactions was then investigated. As shown in, these mild oxidative reactions cover a broad substrate scope including farnesol, 1-acetyldimethyl-2-phenyl-cyclohexanecarboxaldehyde, 5-cyanoindole, 6-pentanol, alkyl ethanol and a variety of acrylates. It is important to note that the presence of 1, 4-dicarboxaldehyde did not preclude any reaction with these farnesol and acrylate substrates at room temperature. In addition, a wide range of electronically and sterically distinct substrates 2428 were tolerated in this reaction.  Last, and perhaps most important, the reaction tolerated electron-donating nitrogen atoms on the trifluoroacetophenone ring. Notably, cyclic nucleophiles with a trifluoroacetophenone trifluorophenate motif can also be realized via this dual-catalysis strategy. 8b, d Recently, a strategy under attack from many lines of attack from various biological, chemical and pharmaceutical toxicologists has become the production of enantioenriched natural products and bioactive compounds. Enantioenriched natural products and bioactive compounds have the potential to alter drug discovery. As such, selective access to enantioenriched and selectively used natural products could have wide implications for biological agent discovery.  While a catalyst in the form of peptide 4 that bears a diazirine-binding motif can only be found in the CNS, its enantiopurity can be increased from 15 ee when the substrate is in the peripheral part of the CNS to 32 ee when the substrate is in the brain.  The enhanced enantioenriched content of 17 is not the only important factor that contributes to this dual catalysis strategy. The chirality in 2 also plays a significant role in the reaction, as it can either aid in the discrimination of the pyridine direction of the trifluoroacetophenone aldol or the olefin to be oriented toward 2 can allow for reactivity with 5 to give 4. 3 instead of 4. 2 and 32 ee in favor of 8.  While natural products are thought to be able to catalyze their own bifurcation, enantioselective reactions of up to 50:1 between 2 and 8 can also be realized
# with up to 99:1 anti-selectivity, albeit with a minimal amount of diastereocontrol. The asymmetric asymmetric catalytic asymmetric BaeyerVilliger reaction of up to 87 ee between 2 and 11 also supports the hypothesis that the stereochemistry of 6 is important for this process.  The BaeyerVilliger reaction of up to 83 ee between 2 and 11 has been established to be an important entry in the development of anti-syn strategies and is a particularly intriguing example because of its similarity to the enantiodivergent BaeyerVilliger reaction in which peptide 4 reacts with one enantiomer of -4 to form 2. This reaction has also been exploited to develop the first enantioselective Barthold strategy in asymmetric BaeyerVilliger reactions. The chemical complexity of the related reactions, coupled with their high barriers to general solution strategies, have made the development of general strategies to access stereochemical control difficult. But, Lewis acids and Lewis bases are able to exert a small amount of stereocontrol in asymmetric BaeyerVilliger reactions more challenging.  One approach to asymmetric transition metal-catalyzed BaeyerVilliger reactions uses stoichiometric activation to induce stereocontrol in the production of diketopiperazines, which are simple alkyl-substituted compounds that are readily accessible to ligands. However, catalytic asymmetric BaeyerViger reactions tend to be much more complicated and are more severely limited by the kinetic impurities of the key reaction partners. Furthermore, due to the high substituents, the stoichiometric activation approaches have been much more limited. For example, in the most common approach, a simple ketone or a simple aldehyde be employed as a substrate, a biphasic mixture of monoener and silyl-substituted is readily achieved. As the reaction concentration increases, the enantiocontrol changes and the selectivity increases. However, catalyst loadings are typically less than 10 mol, making the process asymmetric. To further maximize the potential of this reaction, several novel catalyst classes have been proposed, including Lewis basesand Lewis acids.  The enantioselective implementation of alcohol within peptide-catalyzed asymmetric BaeyerVilliger reactions has long been established as an important strategy for the development of biologically active compounds. As early as 1977, Martin and We observed that peptides containing benzylic alcohol
# [1610 | 1805.57] loss=0.78 avg=1.96
# [1620 | 1815.65] loss=0.82 avg=1.94
# [1630 | 1825.72] loss=0.35 avg=1.92
# [1640 | 1835.80] loss=2.68 avg=1.93
# [1650 | 1845.88] loss=1.30 avg=1.92
# [1660 | 1855.96] loss=0.80 avg=1.91
# [1670 | 1866.04] loss=2.45 avg=1.92
# [1680 | 1876.12] loss=2.74 avg=1.93
# [1690 | 1886.21] loss=2.29 avg=1.93
# [1700 | 1896.29] loss=1.67 avg=1.93
# [1710 | 1906.38] loss=1.11 avg=1.92
# [1720 | 1916.47] loss=1.68 avg=1.91
# [1730 | 1926.56] loss=1.14 avg=1.91
# [1740 | 1936.64] loss=2.15 avg=1.91
# [1750 | 1946.72] loss=1.20 avg=1.90
# [1760 | 1956.80] loss=0.48 avg=1.88
# [1770 | 1966.89] loss=1.27 avg=1.88
# [1780 | 1976.97] loss=0.51 avg=1.86
# [1790 | 1987.05] loss=1.01 avg=1.85
# [1800 | 1997.14] loss=0.53 avg=1.83
# ======== SAMPLE 1 ========
# . 1. 1-Naphthyl-substituted tetramer P1. Phosphate isomer 5. 1. 3-Naphthyl-substituted d-Pro-X has been shown to be more effective than N-methylimidiazole in inhibiting PI3P phosphorylation of bovine ovarian steroids.  However, the effect of substituents near the 4-position of the inhibitor was less clear and perhaps more significant. Substituents on the 6-position reduce the binding energy of the substrate and thus the selectivity of the enzyme. In the context of drug discovery, an amino acid appended to a receptor that displays low protein affinity has been shown to act as an effective phosphorylating agent. Thus, peptides containing the C-terminal N-methyl imidazole showed reduced phosphorylation of the bovine steroid 9. 2. The exact role of the C-terminal position in the catalytic phosphorylation response is not currently understood. However, preliminary studies show that the C-terminal position does indeed confer significant activity in the inhibition of the PI3P phosphorylation of bovine steroid 9. 2.  A more detailed study of the role of the C-terminal position in the enantioselective phosphorylation reaction was accomplished with peptides 9. 3 and 9. 4, in which the C-terminal position is made as the trans subunit. In this arrangement, the phenyl ring is directed inward toward the chiral skeleton to form a more compact structure. Phenyl ring users with a trans-ris side chain on the bovine steroid scaffold exhibited no significant effect on the enantioselectivity measured against controls or against the peptide, while an appended amide greatly affected the enantiomeric excess of the corresponding enantiomer 19. 1. These data show that the absolute steric size of the side chain of the aromatic residue does not significantly affect the enantioselectivity of the enzyme in the phosphorylation of 9. 4. Furthermore, compounds possessing the C-terminal amide were examined as substrates for the PI3P enzyme. As shown in the, compounds in which the benzyl group of the amide, rather than a methyl group, is oriented in the plane defined by the -carbons of the amide groups provide the highest enantioselectivities with a possible increase in yield. Thus, compounds in which the phenyl ring is oriented in the plane were found to be particularly effective substrates for the PI3P enzyme.  Although the C-terminal position is the most remote from the functional group and also the most important, the second and third in the chain are even further from the functional group and the site of phosphorylation. Phenyl ring users with a trans-ris side chain on the imidazole moiety of 9. 5 were particularly effective in the PI3P kinetic resolution with catalysts 9. 6 and 9. 7 using a k rel k ent-2 0. 44. These data show that an intramolecular hydrogen bond between the benzyl group of the side chain of the imidazole and the amide of the bovine leads to the highest enantiomeric excess of the product. However, aromatic compounds, which are less sterically demanding, were not as successful as the less sterically demanding aromatic substrates.  In order to gain further insight into the nature of the remote side chain, we performed a DFT calculation to determine the energy difference between the conformers of the C-terminal and the A-terminal residues in terms of their contribution to selectivity. DFT calculations point to a transition state with the imidazole as the active catalyst, for which the energy difference for the A-terminal residue is 0. 06. The lowest energy transition states for both the A-terminal and the C-terminal residues are considered in. The relative energies given in are as of June 15, 2007, the latest available data for the A-terminal side chain. The energy difference is mainly attributed to differences in solvation. The A-terminal side chain is more soluble in water than the C-terminal side chain. DFT calculations point to conformers in equilibrium with the A-terminal side chain being the most soluble species.  NMR Analysis of Peptid ...
#
# [1810 | 2026.99] loss=1.44 avg=1.83
# [1820 | 2037.06] loss=3.13 avg=1.84
# [1830 | 2047.14] loss=2.11 avg=1.85
# [1840 | 2057.22] loss=1.43 avg=1.84
# [1850 | 2067.30] loss=2.43 avg=1.85
# [1860 | 2077.38] loss=3.14 avg=1.86
# [1870 | 2087.46] loss=0.11 avg=1.84
# [1880 | 2097.55] loss=0.35 avg=1.83
# [1890 | 2107.63] loss=0.72 avg=1.81
# [1900 | 2117.71] loss=2.32 avg=1.82
# [1910 | 2127.80] loss=1.67 avg=1.82
# [1920 | 2137.88] loss=0.52 avg=1.80
# [1930 | 2147.96] loss=0.16 avg=1.78
# [1940 | 2158.06] loss=0.18 avg=1.76
# [1950 | 2168.15] loss=0.89 avg=1.75
# [1960 | 2178.23] loss=0.63 avg=1.74
# [1970 | 2188.31] loss=1.29 avg=1.74
# [1980 | 2198.39] loss=1.37 avg=1.73
# [1990 | 2208.48] loss=0.84 avg=1.72
# [2000 | 2218.56] loss=2.33 avg=1.73
# Saving checkpoint/run1/model-2000
# WARNING:tensorflow:From /gpfs/loomis/project/miller/mhs65/conda_envs/gpt/lib/python3.6/site-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ======== SAMPLE 1 ========
# ...
#
# [11410 | 12692.30] loss=0.06 avg=0.12
# [11420 | 12702.36] loss=0.11 avg=0.12
# [11430 | 12712.43] loss=0.09 avg=0.12
# [11440 | 12722.50] loss=0.12 avg=0.12
# [11450 | 12732.57] loss=0.24 avg=0.12
# [11460 | 12742.65] loss=0.10 avg=0.12
# [11470 | 12752.73] loss=0.08 avg=0.12
# [11480 | 12762.82] loss=0.10 avg=0.12
# [11490 | 12772.89] loss=0.18 avg=0.12
# [11500 | 12782.98] loss=0.09 avg=0.12
# [11510 | 12793.05] loss=0.09 avg=0.12
# [11520 | 12803.12] loss=0.09 avg=0.12
# [11530 | 12813.19] loss=0.10 avg=0.12
# [11540 | 12823.27] loss=0.12 avg=0.12
# [11550 | 12833.35] loss=0.09 avg=0.12
# [11560 | 12843.43] loss=0.13 avg=0.12
# [11570 | 12853.50] loss=0.11 avg=0.12
# [11580 | 12863.58] loss=0.09 avg=0.12
# [11590 | 12873.66] loss=0.08 avg=0.12
# [11600 | 12883.74] loss=0.08 avg=0.12
# ======== SAMPLE 1 ========
# former is of particular interest in light of the ongoing investigation into the hydrogen-bonding networks of peptides as catalysts of asymmetric phosphorylation.  Kinetic Resolutions of Peptide-Accelerated Chaliphatic Phosphorylation in Tandem With Peptide-PLC Enzymes a a a Chakshalypse at K14 and Aib at K56 were coupled by PLC using a cassandra-methodextrin system on behalf of IPQC. The resulting recombinant protein was allowed to equilibrate for 30 min in a sealed tube. After stirring for all allocated reaction time, the reaction was taken out of the ice bath. Phosphorylation of theadyne was monitored by CD intensity in PLCNMe 2 solution.  where I is integration at evolution period t, T 1 is the spinlattice relaxation time, and A is a constant.  Computational Studies of the Peptide-Accelerated Dominant Structural Characteristic of the Crystallographic Sample. The solution structure of the I Na ion was analyzed by computational studies using the program CNS. The on-beada-modified peptide i was found to be stable in the solid state. Additionally, the solution structure of the corresponding tMg ion is shown in. The majority of the structural features of 1a are retained in the solid state structure, including the central tyrocyan oxygen and the C64Phe ion. The only exception is the backbone dihedral angles, which deviate substantially from the canonical values and are significantly wider than that of 1a. These deviations result from conformational aggregation of the single amino acids, which has shown tremendous influence on the spatial attributes of peptides. Furthermore, the angle sampling for the enantioselective phosphorylation of 1a is significantly wider than that of 1a.  In light of the foregoing computational studies, we can propose a explanation of the apparent substrate-controlled site selectivity observed for this phosphorylation reaction. The i 3 residue is oriented such that the sodium and potassium groups are orthogonally aligned, and the long-and short-range NOE correlations display a highly organized, co-and untethered nature. The hydrophobic interactions between the peptide i3 Gly and the amide NH groups are absent, in keeping with a decrease in the solubility of the substrate. More specifically, the hydrophobic interactions between the PhMe of the i3 Gly and the DAla DAla of 1a are reconstructed by the NOESY spectra of 3 and 3 in a coupled way. Moreover, this hypothesis is supported by the so-called co-homologous endo dihedrals, which deviate from the canonical values but are still within the amide product. More specifically, the calculated and dihedrals are found to be compatible with a wide range of structural types. Moreover, the steric demand of the i3 Gly material is accommodated by the steroid ring system. It is fitting, then, that the excellent enantioselectivity is retained aliphatic glucosamine selectivity when using 2 of 12 peptide 2g, a derivative that is unambiguously a pre-helical, type I structure and which has been studied extensively.  It is interesting to note that, while speculative, s ome thoughtsa bout this series included the possibility of an alternative, antagonistic iodine effect where the side chain would be significantly more reactive than the CH bond of the main chain. It was also possible that the Os-OH group of 3 could act as a proper replacement for the Asp-OH group, with H-Asp being optimized for noncatalytic SI reductive elimination, thus leading to the desired diastereochemical equilibrium.  Finally, f ilter, w ed eveloped simulations using the NCIOM package, which enables post-quantitative analysis of the effects of many of the peptides. The use of r ombinatorial formulas as the guiding force for design is particularly powerful. This is especially true in the realm of the peptide designer. T he novel amphiphiles employed in the present study have been employed previously in the automotive industry, and these practices have seen wide usage. Perhaps the most widely utilized appli ...
# [11610 | 12913.32] loss=0.09 avg=0.12
# [11620 | 12923.38] loss=0.14 avg=0.12
# [11630 | 12933.44] loss=0.10 avg=0.12
# [11640 | 12943.50] loss=0.06 avg=0.12
# [11650 | 12953.58] loss=0.10 avg=0.11
# [11660 | 12963.67] loss=0.09 avg=0.11
# [11670 | 12973.74] loss=0.09 avg=0.11
# [11680 | 12983.82] loss=0.12 avg=0.11
# [11690 | 12993.90] loss=0.10 avg=0.11
# [11700 | 13003.98] loss=0.10 avg=0.11
# [11710 | 13014.06] loss=0.08 avg=0.11
# [11720 | 13024.14] loss=0.09 avg=0.11
# [11730 | 13034.21] loss=0.07 avg=0.11
# [11740 | 13044.29] loss=0.12 avg=0.11
# [11750 | 13054.37] loss=0.17 avg=0.11
# [11760 | 13064.45] loss=0.08 avg=0.11
# [11770 | 13074.52] loss=0.13 avg=0.11
# [11780 | 13084.60] loss=0.11 avg=0.11
# [11790 | 13094.67] loss=0.07 avg=0.11
# [11800 | 13104.75] loss=0.15 avg=0.11
# ======== SAMPLE 1 ========
#  technological 1g and P14. Given the magnitude of the effect, P19 was found to be the more selective catalyst, providing 5:1d in 48 h at 25C. Higher rates of racemization under more mild conditions were obtained under the initial reaction conditions. Neopentyl sulfamate, the isolated arginine product, should be distinguished from a monomer into a dimer complex that is axially chiral about the central substituent of the -issociation product. In fact, the observed enantioselectivity is not observed with less than 4 equiv of N-methyl n-pyrrolidinium further suggesting that the P19 selective catalyst, P2, is the more active one. Several additional studies were performed to appraise the relevance of kinetic studies for stereoselective desymmetrization catalysts. It was found that the rate of P19 formation was approximately first order in the absence of catalyst, and that the product distribution was dependent on the identity of the -turn element of the peptide. For example, in the absence of a -turn residue, 5:1d was observed, but under the control of TUR, the enantioselectivity was eroded. It was proposed that this may be due to the flexibility of the cycloheptane core, which could also activate 21 toward S E Ar. However, when a -turn residue was substituted for an -amino acid, the reaction rates were capped, leading to a further erosion in enantioselectivity. A high-murder chiral GC The compound of interest 4, 4-difluoroglutamic acid derivative was isolated from the reaction of P19 with THF. It was found that the flame-dried 100 mL round-bottom flask was able to accommodate the chloromethyl solids of multiple catalysts on the same reaction reagent. These crystals were then purified by column chromatography to afford the crystalline scaffold of D-I-3, 5, 6P 4.  Furthermore, it was observed that the P19 catalyzed reaction deposited only trans-stenophilic residues with the C-terminus of the substrate, whereas the P32 catalyzed reaction, which is biased to favor the axial C-H bond, gave l-I-3, 5, 6P 4.  The reports from the laboratories of P32 and P19 displayed a strong correlation between structure and catalyst activity. Therefore, the crystals from the S2 archive were crystallized with both D-and L-Ala-Trp-OMe as the catalyst. The advantage of the two catalysts is that D-I-3, 5, 6P4 and D-I-3, 5, 6P2 exist as closely related mixtures of the C-terminus residues. The observation that both D-I-3, 5, 6P4 and D-I-3, 5, 6P2 exist in the same conformation with the same set of properties is intriguing. This appears to be true for Con-and D-I-1A as well as L-and L-Asn-OMe. The challenge of the C-terminus of D-I-3, 5, 6P4 is solved by the alanine monomer, which is quite close to covalent catalysis.  The challenge of asymmetric catalysis, in terms of both reactivity and selectivity, is often manifested in drug discovery projects, and also in the synthesis of the natural product. Therefore, the synthesis of alternative monomers, such as L-Asn and L-Leu, may be possible chemoselectively through the action of catalyst 1. As in the case of the nitroesters, an enantioselective catalyst can be identified that provides an asymmetric array for the creation of either L-Asn or L-Leu.  This structure has been studied in many contexts and, importantly, has led to a number of biologically active compounds. Therienzman, R. , Jr. , and co-workers have pursued the total synthesis of D-I-3, 5, 6P4 on the basis of materials provided by the authors. The synthesis was thereafter redirected to D-I-3, 5, 6P3.  In 2007, Jrgensen and co-workers further investigated the concept of merging photoredox and transition metal catalysis, and a dual photoredox palladium catalyst system was designed that enabled C-H arylation of 2-arylpyridines with aryl diazonium salts. Prior to this report, palladium-catalysed C-H arylation protocols typically required the presence of strong oxidants andor elevated temperatures. By merging photoredox and palladium catalysis, the outlined C- ...
#
# [11810 | 13134.36] loss=0.17 avg=0.11
# [11820 | 13144.42] loss=0.12 avg=0.11
# [11830 | 13154.49] loss=0.10 avg=0.11
# [11840 | 13164.56] loss=0.10 avg=0.11
# [11850 | 13174.64] loss=0.14 avg=0.11
# [11860 | 13184.72] loss=0.30 avg=0.12
# [11870 | 13194.80] loss=0.09 avg=0.12
# [11880 | 13204.88] loss=0.16 avg=0.12
# [11890 | 13214.96] loss=0.17 avg=0.12
# [11900 | 13225.04] loss=0.11 avg=0.12
# [11910 | 13235.12] loss=0.11 avg=0.12
# [11920 | 13245.19] loss=0.13 avg=0.12
# [11930 | 13255.26] loss=0.09 avg=0.12
# [11940 | 13265.34] loss=0.11 avg=0.12
# [11950 | 13275.42] loss=0.08 avg=0.12
# [11960 | 13285.49] loss=0.08 avg=0.12
# [11970 | 13295.58] loss=0.12 avg=0.12
# [11980 | 13305.66] loss=0.06 avg=0.12
# [11990 | 13315.73] loss=0.07 avg=0.11
# [12000 | 13325.81] loss=0.08 avg=0.11
# Saving checkpoint/run1/model-12000
# ======== SAMPLE 1 ========
#  tr for the most part. A small number of peptides that provide highly selective for the 6, 7-position are known to adopt -type turns that are significantly different from the canonical turns. More recently, it has been reported that a -turn-biased H-bond may be present in the solid state. The effects of this structure on enantioselectivity are now under study. In particular, the reaction is conceivable that a -turn may form in situ, which would violate the backbone symmetry. Despite these facts, we have not yet observed a catalytic mechanism that can explain the true function of these -turn-containing tetrapeptides.  Our studies began with an examination of the intramolecular Stetter cyclization depicted in eqn. 2. In terms of a catalyst scaffold, we examined simple derivatives of Taz in order to establish whether or not the single residue would provide a catalytically active substructure. To our surprise, simple derivatives of the single amino acid proved to afford appreciable selectivity in the cyclization. When catalyst 4a was employed under optimized conditions, a modest selectivity of 42 ee was observed in the product, which was isolated in low yield. Of note, when the urethane nitrogen was alkylated as in catalyst 4b, the enantioselectivity was completely eroded. The nature of the nitrogen protecting group was also found to have a substantial effect on selectivity. For example, exchange of BOC for acetyl resulted in an increase in both yield and selectivity. Examination of tosyl amides also provided an improvement with catalyst 4d delivering 70 ee at low conversion. The l-isyl amide group provides superior enantiocontrol resulting in 92 ee at low conversion. The results also demonstrate that two different classes of catalysts can be successfully employed to isolate specific benefits from the various functional groups listed.  The results of these studies are particularly intriguing in light of the number of known functional groups that appear to be resistant to oxidation. As noted above, various ketones are known to be poor substrates for classical thermal methods, which requires a very rapid in situ electron oxidation to establish the key oxidative addition step. Moreover, ketones that are intrinsically stable toward oxidation are suitable substrates for the Stetter family of catalysts.  Given the analogy, we also evaluated plain old tetrapeptide catalysts in a bifunctional capacity. Thus, we began with catalyst 4 as a benchmark to be used for screening this study.  Catalyst 4 Evaluation with naphthyl-N-acetyl-N-phenylacetamide. Title compound was prepared from naphthyl-N-acetyl-phenylacetamide according to the procedure outlined in the Supporting Information.  Studies of the stereoselective reduction of amino acid derivatives to the corresponding amino acid derivatives in the presence of the trifluoromethyl groups began with the examination of simple derivatives of Titisen alkal, in which the lacman-like transition state was represented. We were interested in determining whether or not the simple derivatives of dalkindole would participate in the desired reduction. To our surprise, simple derivatives of the alkaloid were ineffective at preventing the dimerization of DeS. Moreover, all attempts to access the dimerization product using either chloro or halogen had thus far failed. On the other hand, introduction of acetyl groups in the meta-position of the phenyl rings provided moderate yields of the desired dimer, which was isolated in good yield for 7a and 8a.  The production of additional stereoisomers of 8a was accomplished in good yield for catalyst 4d. Treatment of 8a with TMSN 3, t-BuCO 2, and Et 3 N in presence of catalytic CuI 3 provided the desired tetrapeptide in 70 yield. The reaction medium was also critically involved in the reaction since it was found that the reaction rate of the trialkyl group was significantly decreased in the presence of chloro or halogen monomers. Following the reaction, to assay the  ...
# [12010 | 13359.07] loss=0.11 avg=0.11
# [12020 | 13369.12] loss=0.16 avg=0.11
# [12030 | 13379.18] loss=0.11 avg=0.11
# [12040 | 13389.25] loss=0.08 avg=0.11
# interrupted
# Saving checkpoint/run1/model-12046

# %% [markdown]
# ### Text generation
#
# We passed in a `prefix` to the generate function to force the text to start with a given character sequence. We chose prefixes that might prompt the model to generate new ideas, such as "Photoredox catalysis can be applied to...".
#
# The `batch_size` option allows the generation of multiple samples in parallel, affording a speedup. The `top_p` option limits the generated guesses to a cumulative probability.

# %%
gen_file = 'gpt2_gentext_{:%Y%m%d_%H%M%S}_0.85.txt'.format(datetime.utcnow())

gpt2.generate_to_file(sess,
                      destination_path=gen_file,
                      length=250,
                          prefix="Peptide catalysis can be applied to",
                      temperature=0.85,
                      nsamples=200,
                      batch_size=10
                      )
