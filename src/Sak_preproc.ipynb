# %% [markdown]
# # CHEM 584 Machine Learning Project
# ## Marcus Sak
#
# ### Preprocessing
#
# This notebook takes in a folder containing TEI-formatted `xml` files generated from PDFs of research articles, and exports single-column `.csv` files with the abstract, body text, title and abstract, as well as title and body text of the articles.

# %% [markdown]
# ### Imports

# %%
import os
import re
import csv
import glob
import pandas as pd
from pathlib import Path
import multiprocessing as mp
from bs4 import BeautifulSoup
from os.path import basename, splitext

# %% [markdown]
# ### Defining TEIFile class and utility functions

# %%
# The following code is modified from https://komax.github.io/blog/text/python/xml/parsing_tei_xml_python/

def full_path(filename):
    """ Generates a full path of a file from the input filename, assuming that the file is in the current directory
    """
    script_dir = os.path.dirname(__file__)
    rel_path = filename
    return os.path.join(script_dir, rel_path)

def read_tei(tei_file):
    """ Parses the xml file and returns a soup object containing all the data in the file as a tree
    """
    with open(tei_file, 'r') as tei:
        soup = BeautifulSoup(tei, 'lxml')
        return soup
    raise RuntimeError('Cannot generate a soup from the input')

class TEIFile(object):
    def __init__(self, filename):
        self.filename = filename
        self.soup = read_tei(filename)
        self._text = None
        self._title = ''
        self._abstract = ''
        self._date = None
        #filter terms to exclude from text: acknowledgements and experimental
        self._filter = ['thank', 'acknowledg', 'nih', 'nsf', 'http', 'experimental procedure', \
                        'www.', 'co-wrote', 'authors declare', 'grateful', 'yale', 'silica gel', 'ppm',\
                        'free of charge', 'crystallographic data', 'mail', 'experimental details', 'see:']
    
    @property
    def date(self):
        if not self._date:
            self._date = self.soup.date.getText()
        return self._date
    
    @property
    def title(self):
        if not self._title:
            self._title = self.soup.title.getText()
            self._title = self._text_process(self._title)
        return self._title

    @property
    def abstract(self):
        if not self._abstract:
            abstract = self.soup.abstract.getText(separator=' ', strip=True)
            abstract = self._text_process(abstract)
            self._abstract = abstract
        return self._abstract
    
    @property
    def text(self):
        if not self._text:
            divs_text = []
            for div in self.soup.body.find_all("div"):
                # div is neither an appendix nor references, just plain text.
                if not div.get("type"):
                    for ref in div.find_all("ref"): 
                        ref.decompose()  # remove references to citations and figures
                    for p in div.find_all('p'):
                        p_text = p.get_text(separator='', strip=True)  # returns one chunk of text without markdown
                        p_text = self._text_process(p_text)
                        
                        if all(term not in p_text.lower() for term in self._filter):
                            # skip paragraphs of acknowledgements, etc
                            divs_text.append(p_text)
                            
            self._text  = divs_text            
        return self._text
    
    def _text_process(self, string):
        """ Strips everything in parens, handles proper punctuation, symbols, etc.
        """
        string = re.sub("[\(\[].*?[\)\]]", "", string)
        string = re.sub(r'[^A-Za-z0-9 ,.\-:]+', '', string)
        string = re.sub(" +", " ", string)  # handle double spaces
        string = re.sub(" \.", ".", string)  # space before period
        string = re.sub(" ,", ",", string)  # space before comma
        string = re.sub(r'((?!\w)\.(?!\ |^\w))', '. ', string)  # no space before and after period
        string = re.sub(r'((?!\w),(?!\ |^\w))', ', ', string)  # no space before and after comma
        return string

# %%
def tei_to_csv_entry(tei_file):
    tei = TEIFile(tei_file)
    print(f"Handled {tei_file}")
    return tei.title, tei.date, tei.abstract, tei.text

# %% [markdown]
# ### Testing on one file

# %%
tei_doc = 'tei_papers/364.full.tei.xml'

# %%
tei_file = 'tei_papers/364.full.tei.xml'
tei_to_csv_entry(tei_file)
# Out:
# Handled tei_papers/364.full.tei.xml
# ('Light-driven deracemization enabled by excited-state electron transfer',
#  '18 October 2019',
#  'Deracemization is an attractive strategy for asymmetric synthesis, but intrinsic energetic challenges have limited its development. Here, we report a deracemization method in which amine derivatives undergo spontaneous optical enrichment upon exposure to visible light in the presence of three distinct molecular catalysts. Initiated by an excited-state iridium chromophore, this reaction proceeds through a sequence of favorable electron, proton, and hydrogen-atom transfer steps that serve to break and reform a stereogenic C-H bond. The enantioselectivity in these reactions is jointly determined by two independent stereoselective steps that occur in sequence within the catalytic cycle, giving rise to a composite selectivity that is higher than that of either step individually. These reactions represent a distinct approach to creating out-of-equilibrium product distributions between substrate enantiomers using excited-state redox events. RESEARCH',
#  ['We first observed deracemization behavior serendipitously while attempting to develop an asymmetric variant of a previously reported hydroamidation reaction mediated by an Ir-based photoredox catalyst, a dialkyl phosphate base, and an aryl thiol H-atom donor under visible light irradiation. We found that the use of chiral BINOL phosphates as Brnsted bases was effective in this chemistry and resulted in a modest amount of enantioselectivity. However, timecourse studies unexpectedly revealed that the urea product 1b was initially formed as a racemate but became slightly optically enriched during the course of the reaction. In subsequent control reactions, we subjected racemic 1b to the reaction conditions and observed significant optical enrichment with near-complete material recovery, indicating that a light-driven deracemization pathway was operative. Similarly, when enantiopure -1b was subjected to identical conditions using an achiral phosphate base, racemization of the stereogenic C-H bond was observed. ',
#   'To evaluate this hypothesis, we elected to further study the deracemization of N-arylsubstituted cyclic ureas. Preliminary studies demonstrated that a pendant amide H-bond donor group is crucial for obtaining high selectivities in the enantioselective deprotonation step using the chiral phosphate bases, prompting us to evaluate the deracemization of urea 2a as a model substrate. A small collection of BINOLderived phosphate bases were explored with ppy 2 PF 6 and an achiral thiophenol H-atom donor catalyst in tetrahydrofuran under irradiation with blue lightemitting diodes at room temperature. Although a BINOL-derived phosphate with 1-adamantyl groups gave essentially racemic product, an analogous catalyst bearing phenyl groups gave an improved er of 69:31. We hypothesized that there might be a stabilizing p-cation interaction between the oxidized substrate radical cation and the aryl substituents of chiral phosphate, prompting us to examine catalysts bearing more expansive aryl substituents. This in turn led to catalyst 3e, which gave 79:21 er and good yield. The addition of molecular sieves further improved the selectivity to 86:14 er. ',
#   'With these optimized deracemization conditions in hand, we found that a variety of structural changes in the urea substrate could be accommodated. Alkyl substituents of varying steric demand could be tolerated at the stereogenic carbon with uniformly good levels of enantioselectivity. Substitution of the distal urea nitrogen with the free N-H amide, benzyl, or isopropyl groups also provided the desired deracemized products with high levels of stereoselectivity. Structural changes on the acyclic amide moiety were also tolerated, as was a benzamide derivative. However, an N, N-dimethyl amide variant demonstrated a noticeable decrease in the er. Upon reaching the steady-state level of optical enrichment, all of the substrates studied here can be recovered in nearly quantitative yield. '])

# %% [markdown]
# ### Process all files

# %%
# return all files in the folder tei_papers
papers = sorted(Path("./tei_papers").glob('*.tei.xml'))

# use multiprocessing to parse in parallel
pool = mp.Pool()
csv_entries = pool.map(tei_to_csv_entry, papers)

result_csv = pd.DataFrame(csv_entries, columns=['Title', 'Date','Abstract', 'Text'])
result_csv
# Out:
# Handled tei_papers/364.full.tei.xmlHandled tei_papers/a-fluorination.tei.xml
# Handled tei_papers/a-trifluoromethylation_iodonium.tei.xmlHandled tei_papers/Alpha-Amination.tei.xmlHandled tei_papers/1-s2.0-S004040200600281X-main.tei.xml
#
#
#
# Handled tei_papers/SOMOenolation.tei.xmlHandled tei_papers/CopperVinylation.tei.xmlHandled tei_papers/1-s2.0-S0040402003012808-main.tei.xmlHandled tei_papers/acs.orglett.8b00364.tei.xml
# Handled tei_papers/a-nitroalkylation.tei.xmlHandled tei_papers/Direct-arylation-of-strong-aliphatic-C–H-bonds.tei.xmlHandled tei_papers/A-radical-approach-to-the-copper-oxidative-addition-problem.tei.xml
# Handled tei_papers/HomoEne.tei.xml
#
# Handled tei_papers/acscentsci.6b00237.tei.xmlHandled tei_papers/aldehyde-aldol.tei.xml
#
# Handled tei_papers/Vincorine.tei.xml
#
# Handled tei_papers/Decarboxylativ-sp3-C-N-coupling.tei.xmlHandled tei_papers/SOMOmechanism.tei.xml
#
# Handled tei_papers/Copper-Catalyzed-Trifluoromethylation-of-Alkyl-Bromides.tei.xmlHandled tei_papers/Tomer-Paper.tei.xml
#
#
# Handled tei_papers/Open-Shell-Fluorination-of-Alkyl-Bromides_-Unexpected-Selectivity-in-a-Silyl-Radical-Mediated-Chain-Process.tei.xmlHandled tei_papers/SOMO-Pyrrolidines.tei.xmlHandled tei_papers/Gorlova2017_Article_IdentificationAndPartialStruct.tei.xmlHandled tei_papers/C-H-alcohol-alkylation.tei.xml
# Handled tei_papers/380.full_.tei.xml
#
# Handled tei_papers/1-s2.0-S0040403910020873-main.tei.xml
#
#
#
# Handled tei_papers/adsc.201500230.tei.xmlHandled tei_papers/PIIS2451929419304577.tei.xml
# Handled tei_papers/Mukaiyama-Michael-1.tei.xmlHandled tei_papers/1-s2.0-S0008621513003649-main.tei.xmlHandled tei_papers/Tracy_Orgcat.tei.xml
# Handled tei_papers/a-arylation.tei.xmlHandled tei_papers/SOMOscience.tei.xml
# Handled tei_papers/EOHR.tei.xml
# Handled tei_papers/Arene-Trifluoromethylation.tei.xml
# Handled tei_papers/acs.orglett.9b02214.tei.xmlHandled tei_papers/IMDA.tei.xml
#
#
# Handled tei_papers/acs.joc.8b03068.tei.xml
#
# Handled tei_papers/1-s2.0-S1388198116302384-main.tei.xmlHandled tei_papers/acscatal.9b03535.tei.xmlHandled tei_papers/a-trifluoromethylation.tei.xml
# Handled tei_papers/aldehyde-alkylation-S-HAT2.tei.xml
#
#
# Handled tei_papers/SOMO-cycloaddition.tei.xmlHandled tei_papers/Mechanistic-Analysis-of-Metallaphotoredox-C-N-Coupling.tei.xml
#
#
#
#
# Handled tei_papers/SOMOmechanism2.tei.xmlHandled tei_papers/1-s2.0-S0040402004008816-main.tei.xmlHandled tei_papers/acs.accounts.8b00473.tei.xmlHandled tei_papers/Decarboxylative_Fluorination.tei.xml
# Handled tei_papers/acs.joc.0c01147.tei.xml
#
#
# Handled tei_papers/Copper-alpha-amination.tei.xmlHandled tei_papers/SOMOvinylation.tei.xmlHandled tei_papers/1-s2.0-S0040402006007514-main.tei.xmlHandled tei_papers/Cross-Electrophile-Coupling-of-aliphatic-bromides.tei.xml
#
# Handled tei_papers/OrgSynPrep.tei.xmlHandled tei_papers/HARC-as-an-open-shell-strategy-to-bypass-oxidative-addition-in-Ullmann–Goldberg-couplings.tei.xml
#
#
# Handled tei_papers/a-benzylation.tei.xmlHandled tei_papers/ab-epoxidation.tei.xmlHandled tei_papers/alcohol-hat-arylation2.tei.xmlHandled tei_papers/acs.orglett.9b00624.tei.xmlHandled tei_papers/acscentsci.9b00460.tei.xml
#
#
# Handled tei_papers/CO2ExR-ketones.tei.xmlHandled tei_papers/Accelerated-Serendipity.tei.xml
#
# Handled tei_papers/Fu_collab.tei.xml
#
#
# Handled tei_papers/aldehyde-alpha-arylation.tei.xmlHandled tei_papers/Transient-Absorption-Spectroscopy.tei.xml
#
# Handled tei_papers/Indole-Arylation.tei.xmlHandled tei_papers/1-s2.0-S004040200000884X-main.tei.xmlHandled tei_papers/702.full.tei.xmlHandled tei_papers/Nickel-Photo-Vinylation.tei.xml
#
#
# Handled tei_papers/Diels-Alder.tei.xmlHandled tei_papers/alpha-oxidation.tei.xmlHandled tei_papers/SOMO_ketone.tei.xmlHandled tei_papers/acylclaisen.tei.xml
#
#
#
#
#
# Handled tei_papers/1-s2.0-S0960894X15303401-main.tei.xml
# Handled tei_papers/acs.jpclett.9b01091.tei.xmlHandled tei_papers/anie.200601490.tei.xml
# Handled tei_papers/OxyAllylCation.tei.xmlHandled tei_papers/asymmclais.tei.xmlHandled tei_papers/BetaArylation.tei.xmlHandled tei_papers/aniline-addition.tei.xml
# Handled tei_papers/AllylicArylation.tei.xml
# Handled tei_papers/1-s2.0-S0040402005006101-main.tei.xmlHandled tei_papers/acscentsci.0c00024.tei.xml
#
# Handled tei_papers/Metallaphotoredox-Difluoromethylation-of-Aryl-Bromides.tei.xml
# Handled tei_papers/aldehyde-CH-X-coupling2.tei.xml
#
#
# Handled tei_papers/DKR.tei.xml
# Handled tei_papers/1-s2.0-S0040403907001220-main.tei.xmlHandled tei_papers/1251.full.tei.xml
#
# Handled tei_papers/carbo-oxidation.tei.xml
#
#
# Handled tei_papers/Chen_et_al-2019-Angewandte_Chemie_International_Edition.tei.xmlHandled tei_papers/NickelandPhotoredox.tei.xmlHandled tei_papers/Copper-mediated-synthesis-of-drug-like-bicyclopentanes.tei.xml
# Handled tei_papers/b-BF3Kaddition.tei.xml
#
# Handled tei_papers/anie.201109033.tei.xml
# Handled tei_papers/HIE2.tei.xml
# Handled tei_papers/amine_alpha_vinylation.tei.xmlHandled tei_papers/c3ob40924d.tei.xml
# Handled tei_papers/anie.200900480.tei.xmlHandled tei_papers/acs.accounts.6b00613.tei.xmlHandled tei_papers/buchwaldcollab-1.tei.xml
# Handled tei_papers/aoxidation.tei.xml
# Handled tei_papers/b304015c.tei.xmlHandled tei_papers/acs.orglett.6b02282.tei.xml
#
# Handled tei_papers/acs.orglett.9b04119.tei.xml
#
# Handled tei_papers/anie.201802963.tei.xmlHandled tei_papers/beta-Ketone-coupling.tei.xml
# Handled tei_papers/Minovincine.tei.xmlHandled tei_papers/c6cc01428c.tei.xml
# Handled tei_papers/1-s2.0-S1367593102003241-main.tei.xmlHandled tei_papers/acs.orglett.9b00707.tei.xml
#
#
#
#
#
#
#
# Handled tei_papers/b-amination.tei.xml
# Handled tei_papers/ja011675k.tei.xmlHandled tei_papers/ja027402m.tei.xmlHandled tei_papers/aldrichimica.tei.xmlHandled tei_papers/carbohydrate.tei.xml
# Handled tei_papers/cyanoalkylation.tei.xmlHandled tei_papers/ether-arylation.tei.xmlHandled tei_papers/decarboxylative_alkylation.tei.xml
#
#
# Handled tei_papers/b414574g.tei.xmlHandled tei_papers/intramolecular-aldehyde-alpha-allylation.tei.xmlHandled tei_papers/ja049661c.tei.xml
#
#
#
# Handled tei_papers/acs.joc.7b02339.tei.xml
# Handled tei_papers/ja0466098.tei.xmlHandled tei_papers/20620.full.tei.xml
#
#
#
# Handled tei_papers/anie.201505898.tei.xmlHandled tei_papers/ja073055a.tei.xmlHandled tei_papers/ja0377798.tei.xmlHandled tei_papers/beta-mannich.tei.xmlHandled tei_papers/anie.201101147.tei.xml
# Handled tei_papers/cascade.tei.xmlHandled tei_papers/Synergistic-catalysis.tei.xml
#
# Handled tei_papers/ja0055763.tei.xmlHandled tei_papers/ja016779+.tei.xmlHandled tei_papers/hydrogenation-account.tei.xml
# Handled tei_papers/amine_heteroarylation.tei.xml
#
#
#
#
# Handled tei_papers/ja067139f.tei.xml
#
# Handled tei_papers/ja047360x.tei.xmlHandled tei_papers/anie.201808305.tei.xmlHandled tei_papers/c4sc01440e.tei.xmlHandled tei_papers/butenolide-1.tei.xmlHandled tei_papers/chem.201404560.tei.xml
#
#
# Handled tei_papers/alkyne-deCO2-alkylation2.tei.xmlHandled tei_papers/acscentsci.1c00039.tei.xml
#
#
# Handled tei_papers/diazonamide.tei.xml
#
# Handled tei_papers/ja042650z.tei.xmlHandled tei_papers/ja0177814.tei.xml
# Handled tei_papers/cycle-specific-cascade.tei.xml
# Handled tei_papers/ja047845l.tei.xmlHandled tei_papers/ja0734243.tei.xmlHandled tei_papers/flustramine.tei.xml
# Handled tei_papers/d0cs01366h.tei.xmlHandled tei_papers/ja0108584.tei.xml
# Handled tei_papers/ja984139+.tei.xmlHandled tei_papers/ar030061c.tei.xml
# Handled tei_papers/ja067840j.tei.xmlHandled tei_papers/1-s2.0-S0040402002001229-main.tei.xml
#
#
#
# Handled tei_papers/beta_alkylation.tei.xml
#
# Handled tei_papers/iminium-geometry.tei.xml
# Handled tei_papers/c7sc00099e.tei.xml
# Handled tei_papers/anie.201511750.tei.xmlHandled tei_papers/ether_Minisci.tei.xml
# Handled tei_papers/ja100931y.tei.xml
# Handled tei_papers/allenoate-claisen.tei.xmlHandled tei_papers/JOCperspective.tei.xmlHandled tei_papers/enonehydrog.tei.xmlHandled tei_papers/cyclopropanation.tei.xml
# Handled tei_papers/b816700c.tei.xml
#
#
#
#
# Handled tei_papers/ja901279m.tei.xmlHandled tei_papers/cascadeSynAcct.tei.xml
# Handled tei_papers/indoleca.tei.xmlHandled tei_papers/ja400082x.tei.xmlHandled tei_papers/chlorination.tei.xmlHandled tei_papers/ja508757g.tei.xml
#
#
#
#
#
#
#
# Handled tei_papers/c1sc00221j.tei.xmlHandled tei_papers/c5sc04629g.tei.xmlHandled tei_papers/ja410567a.tei.xmlHandled tei_papers/jo025888j.tei.xml
#
#
# Handled tei_papers/acscatal.8b03563.tei.xml
# Handled tei_papers/jo981642w.tei.xmlHandled tei_papers/ja9931776.tei.xml
# Handled tei_papers/anie.201913563.tei.xmlHandled tei_papers/ja202706g.tei.xml
#
# Handled tei_papers/jacs.7b11303.tei.xml
# Handled tei_papers/ether_schiff_bases.tei.xmlHandled tei_papers/ja9107897.tei.xmlHandled tei_papers/jo702334z.tei.xml
# Handled tei_papers/acs.joc.8b00207.tei.xml
# Handled tei_papers/minfiensine.tei.xml
#
# Handled tei_papers/jo0610816.tei.xmlHandled tei_papers/jo0269013.tei.xml
#
#
# Handled tei_papers/callipeltoside.tei.xmlHandled tei_papers/ol005700n.tei.xml
#
# Handled tei_papers/ja973892k.tei.xmlHandled tei_papers/ja710348r.tei.xmlHandled tei_papers/linchpin-chlorination.tei.xml
#
# Handled tei_papers/co200010v.tei.xmlHandled tei_papers/ol100927m.tei.xml
#
#
# Handled tei_papers/jacs.9b10414.tei.xml
# Handled tei_papers/jacs.7b08775.tei.xml
# Handled tei_papers/nature13273.tei.xml
# Handled tei_papers/jo2018679.tei.xmlHandled tei_papers/frondosin.tei.xml
#
# Handled tei_papers/ja0c04812-1..7.tei.xmlHandled tei_papers/Ketoacid_decarboxylation.tei.xml
#
# Handled tei_papers/ja200849g.tei.xmlHandled tei_papers/ol101947s.tei.xml
# Handled tei_papers/ol303424b.tei.xml
# Handled tei_papers/littoralisone.tei.xmlHandled tei_papers/ja301566t.tei.xmlHandled tei_papers/nickel_etherification.tei.xmlHandled tei_papers/ketone-fluorination.tei.xml
# Handled tei_papers/jacs.8b02650.tei.xml
#
#
#
# Handled tei_papers/ol050780m.tei.xmlHandled tei_papers/ja410750a.tei.xmlHandled tei_papers/jo060702s.tei.xml
#
# Handled tei_papers/oxyaldol.tei.xml
# Handled tei_papers/ja4038998.tei.xml
#
#
#
# Handled tei_papers/nitrone.tei.xml
#
# Handled tei_papers/ol3000712.tei.xmlHandled tei_papers/ol016372+.tei.xmlHandled tei_papers/ol051061a.tei.xmlHandled tei_papers/jacs.0c08057.tei.xml
#
#
#
# Handled tei_papers/ol503593y.tei.xmlHandled tei_papers/ol402381n.tei.xmlHandled tei_papers/pyrroleca.tei.xml
# Handled tei_papers/ja807120z.tei.xml
#
#
# Handled tei_papers/oxyamination_mechanism.tei.xmlHandled tei_papers/jacs.0c03904.tei.xml
#
# Handled tei_papers/pentose_sugars.tei.xml
# Handled tei_papers/deamination.tei.xml
# Handled tei_papers/jo9004316.tei.xml
# Handled tei_papers/PhotoredoxCatalysis.tei.xmlHandled tei_papers/nature-insight.tei.xmlHandled tei_papers/jo971050y.tei.xml
#
#
# Handled tei_papers/tandemclaisen.tei.xmlHandled tei_papers/organocascade-collective-synthesis.tei.xmlHandled tei_papers/decarboxylation-arylation.tei.xmlHandled tei_papers/chem.201102474.tei.xml
# Handled tei_papers/heteroarene-alkylation-alcohol.tei.xml
# Handled tei_papers/jo070676d.tei.xml
# Handled tei_papers/jacs.5b13384.tei.xml
#
# Handled tei_papers/ketoneda.tei.xml
#
# Handled tei_papers/photoredox.tei.xmlHandled tei_papers/ol035466b.tei.xmlHandled tei_papers/nchem.1469.tei.xml
# Handled tei_papers/jacs.7b09176.tei.xml
# Handled tei_papers/peptide-conjugation2.tei.xml
#
#
#
# Handled tei_papers/McCarver_et_al-2016-Angewandte_Chemie_International_Edition.tei.xmlHandled tei_papers/ol0513544.tei.xmlHandled tei_papers/ol9016782.tei.xmlHandled tei_papers/np9004932.tei.xmlHandled tei_papers/nature13189.tei.xml
#
#
#
#
# Handled tei_papers/silylketene-arylation.tei.xmlHandled tei_papers/oxalates-micheal.tei.xmlHandled tei_papers/jm501872s.tei.xmlHandled tei_papers/jacs.9b01911.tei.xmlHandled tei_papers/reductiveamination.tei.xml
# Handled tei_papers/s41557-018-0154-0.tei.xml
#
#
# Handled tei_papers/ol4033072.tei.xml
#
# Handled tei_papers/ja412996f.tei.xml
# Handled tei_papers/polyene.tei.xmlHandled tei_papers/ja302692j.tei.xmlHandled tei_papers/ol9909076.tei.xml
#
# Handled tei_papers/jo101018t.tei.xml
#
# Handled tei_papers/jacs.0c09926.tei.xmlHandled tei_papers/sulfonamide-2.tei.xml
# Handled tei_papers/scienceCHarylation.tei.xmlHandled tei_papers/photoreactor2.tei.xml
#
# Handled tei_papers/jo015803z.tei.xml
#
# Handled tei_papers/thiol.tei.xmlHandled tei_papers/cr068377w.tei.xmlHandled tei_papers/jacs.6b03444.tei.xml
#
# Handled tei_papers/ja406067v.tei.xmlHandled tei_papers/nchem.410.tei.xmlHandled tei_papers/jacs.7b11197.tei.xml
#
# Handled tei_papers/Proximity-Labeling.tei.xmlHandled tei_papers/sp3-alkylation2.tei.xml
#
# Handled tei_papers/jo402828f.tei.xml
#
#
# Handled tei_papers/oxalatesmetallaphoto.tei.xml
# Handled tei_papers/suzuki.tei.xml
#
# Handled tei_papers/ja2014983.tei.xmlHandled tei_papers/polypyrroloindolines2.tei.xmlHandled tei_papers/chem.201300745.tei.xml
#
#
# Handled tei_papers/sp3sp3-decarboxylation.tei.xmlHandled tei_papers/photoredox-carbonyl-alpha-trifluoromethylation.tei.xmlHandled tei_papers/scs-benzylation3.tei.xmlHandled tei_papers/s41557-018-0041-8.tei.xml
#
#
# Handled tei_papers/synergistic-alpha-vinylation.tei.xmlHandled tei_papers/s41557-020-0436-1.tei.xmlHandled tei_papers/cs200406d.tei.xml
#
#
#
# Handled tei_papers/jacs.5b07726.tei.xmlHandled tei_papers/xiangbo.tei.xml
#
# Handled tei_papers/jo501625f.tei.xml
# Handled tei_papers/cs501117h.tei.xml
# Handled tei_papers/silylcrosscoupling.tei.xmlHandled tei_papers/s41586-020-3015-0.tei.xml
#
# Handled tei_papers/metallaphotocatalysis-nat-rev-chem.tei.xmlHandled tei_papers/jacs.6b11348.tei.xml
#
# Handled tei_papers/acs.chemrev.0c00523.tei.xml
# Handled tei_papers/acs.chemrev.7b00022.tei.xml
#                                                  Title              Date  \
# 0    Combined Lewis acid and Brnsted acid-mediated ...   10 October 2013
# 1    Asymmetric Acylation Reactions Catalyzed by Co...
# 2    Amino acids and peptides as asymmetric organoc...
# 3    A peptide-based catalyst approach to regiosele...
# 4    Synthesis of aziridinomitosenes through base-c...
# ..                                                 ...               ...
# 295  The First Suzuki Cross-Couplings of Aryltrimet...
# 296  Enantioselective -Vinylation of Aldehydes via ...      May 22, 2012
# 297  Design of a New Cascade Reaction for the Const...
# 298  Enantioselective organocatalytic aldehyde -ald...      15 July 2004
# 299  Metallaphotoredox Perfluoroalkylation of Organ...  November 9, 2020
#
#                                               Abstract  \
# 0    Biomimetic conditions for a synthetic glycosyl...
# 1    Octapeptides capable of adopting b-hairpin con...
# 2
# 3    Two small peptide libraries have been subjecte...
# 4    Synthesis of an aziridinomitosene core structu...
# ..                                                 ...
# 295
# 296  The enantioselective -vinylation of aldehydes ...
# 297
# 298  An asymmetric proline catalyzed aldol reaction...
# 299  RuppertPrakash type reagents are readily avail...
#
#                                                   Text
# 0    [The structural and functional characterizatio...
# 1    [Small peptides that promote asymmetric reacti...
# 2    [Use of a short peptide as a catalyst would al...
# 3    [The chiral pool continues to represent a trem...
# 4    [Initial studies were performed to determine i...
# ..                                                 ...
# 295  [The transition-metal-catalyzed cross-coupling...
# 296  [Our investigation began with an examination o...
# 297  [Tandem or domino reactions have long been est...
# 298  [The proposed organocatalytic cross aldol was ...
# 299  [I t is well understood that the incorporation...
#
# [300 rows x 4 columns]

# %%
result_csv["Text"]= result_csv["Text"].str.join(" ") 

# join title and body text in a prompt/response format, later found to not be useful
result_csv["Text with title"] = '[T] ' + result_csv["Title"] + ' [A] ' + result_csv["Text"]
result_csv["Abstract with title"] = '[T] ' + result_csv["Title"] + ' [A] ' + result_csv["Abstract"]
result_csv
# Out:
#                                                  Title              Date  \
# 0    Combined Lewis acid and Brnsted acid-mediated ...   10 October 2013
# 1    Asymmetric Acylation Reactions Catalyzed by Co...
# 2    Amino acids and peptides as asymmetric organoc...
# 3    A peptide-based catalyst approach to regiosele...
# 4    Synthesis of aziridinomitosenes through base-c...
# ..                                                 ...               ...
# 295  The First Suzuki Cross-Couplings of Aryltrimet...
# 296  Enantioselective -Vinylation of Aldehydes via ...      May 22, 2012
# 297  Design of a New Cascade Reaction for the Const...
# 298  Enantioselective organocatalytic aldehyde -ald...      15 July 2004
# 299  Metallaphotoredox Perfluoroalkylation of Organ...  November 9, 2020
#
#                                               Abstract  \
# 0    Biomimetic conditions for a synthetic glycosyl...
# 1    Octapeptides capable of adopting b-hairpin con...
# 2
# 3    Two small peptide libraries have been subjecte...
# 4    Synthesis of an aziridinomitosene core structu...
# ..                                                 ...
# 295
# 296  The enantioselective -vinylation of aldehydes ...
# 297
# 298  An asymmetric proline catalyzed aldol reaction...
# 299  RuppertPrakash type reagents are readily avail...
#
#                                                   Text  \
# 0    The structural and functional characterization...
# 1    Small peptides that promote asymmetric reactio...
# 2    Use of a short peptide as a catalyst would all...
# 3    The chiral pool continues to represent a treme...
# 4    Initial studies were performed to determine if...
# ..                                                 ...
# 295  The transition-metal-catalyzed cross-coupling ...
# 296  Our investigation began with an examination of...
# 297  Tandem or domino reactions have long been esta...
# 298  The proposed organocatalytic cross aldol was f...
# 299  I t is well understood that the incorporation ...
#
#                                        Text with title  \
# 0    [T] Combined Lewis acid and Brnsted acid-media...
# 1    [T] Asymmetric Acylation Reactions Catalyzed b...
# 2    [T] Amino acids and peptides as asymmetric org...
# 3    [T] A peptide-based catalyst approach to regio...
# 4    [T] Synthesis of aziridinomitosenes through ba...
# ..                                                 ...
# 295  [T] The First Suzuki Cross-Couplings of Aryltr...
# 296  [T] Enantioselective -Vinylation of Aldehydes ...
# 297  [T] Design of a New Cascade Reaction for the C...
# 298  [T] Enantioselective organocatalytic aldehyde ...
# 299  [T] Metallaphotoredox Perfluoroalkylation of O...
#
#                                    Abstract with title
# 0    [T] Combined Lewis acid and Brnsted acid-media...
# 1    [T] Asymmetric Acylation Reactions Catalyzed b...
# 2    [T] Amino acids and peptides as asymmetric org...
# 3    [T] A peptide-based catalyst approach to regio...
# 4    [T] Synthesis of aziridinomitosenes through ba...
# ..                                                 ...
# 295  [T] The First Suzuki Cross-Couplings of Aryltr...
# 296  [T] Enantioselective -Vinylation of Aldehydes ...
# 297  [T] Design of a New Cascade Reaction for the C...
# 298  [T] Enantioselective organocatalytic aldehyde ...
# 299  [T] Metallaphotoredox Perfluoroalkylation of O...
#
# [300 rows x 6 columns]

# %%
abs_df = result_csv["Abstract"]
abs_df.replace("", float("NaN"), inplace=True)
abs_df.dropna(inplace=True)

# export to csv
result_csv["Text"].to_csv('text_proc.csv', index=False,header=False)
abs_df.to_csv('abs_proc.csv', index=False,header=False)
result_csv["Text with title"].to_csv('text_title_proc.csv', index=False,header=False)
result_csv["Abstract with title"].to_csv('abs_title_proc.csv', index=False,header=False)
